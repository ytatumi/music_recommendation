# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
from recommendation_func import *

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
tracks_df = pd.read_csv("tracks_2000.csv",index_col=[0])

# %%
normalized_tracks_df_withIndex = preprocess(tracks_df)

# %%
normalized_tracks_df_withIndex.head()
# Out:
#                                     title          artist     bpm  energy  \
# 0                                 flowers     miley cyrus 0.38411 0.65957
# 1                       cupid - twin ver.     fifty fifty 0.39735 0.56383
# 2                                    beso         rosalía 0.23179 0.61702
# 3                      boy's a liar pt. 2  pinkpantheress 0.48344 0.79787
# 4  creepin' (with the weeknd & 21 savage)    metro boomin 0.25166 0.59574
#
#    danceability       dB  liveness  valence  duration  acousticness  \
# 0        0.66250 0.77778   0.01220  0.65591   0.14834       0.06122
# 1        0.75000 0.55556   0.40244  0.74194   0.10297       0.44898
# 2        0.73750 0.61111   0.18293  0.52688   0.13962       0.75510
# 3        0.65000 0.55556   0.28049  0.88172   0.02792       0.25510
# 4        0.67500 0.66667   0.07317  0.13978   0.18674       0.42857
#
#    speechiness   popularity
# 0       0.08929     1.00000
# 1       0.01786     0.98925
# 2       0.21429     0.97849
# 3       0.05357     0.97849
# 4       0.05357     0.97849

# %%
normalized_tracks_df_withIndex.describe()
# Out:
#              bpm     energy  danceability          dB   liveness    valence  \
# count 2119.00000 2119.00000     2119.00000 2119.00000 2119.00000 2119.00000
# mean     0.39383    0.67788        0.61281    0.68111    0.19282    0.53920
# std      0.17980    0.17048        0.17115    0.11371    0.16701    0.23959
# min      0.00000    0.05319        0.00000    0.00000    0.00000    0.00000
# 25%      0.25166    0.56383        0.51250    0.61111    0.08537    0.36022
# 50%      0.39735    0.69149        0.62500    0.72222    0.12195    0.53763
# 75%      0.49007    0.80851        0.72500    0.77778    0.25610    0.73118
# max      1.00000    1.00000        0.98750    1.00000    1.00000    1.00000
#
#         duration  acousticness  speechiness   popularity
# count 2119.00000    2119.00000    2119.00000  2119.00000
# mean     0.19334       0.15928       0.14533     0.72192
# std      0.07398       0.20691       0.17065     0.09747
# min      0.00000       0.00000       0.00000     0.50538
# 25%      0.14834       0.02041       0.03571     0.64516
# 50%      0.18674       0.07143       0.07143     0.72043
# 75%      0.22688       0.22449       0.17857     0.79570
# max      1.00000       1.00000       1.00000     1.00000

# %%
title ="Yellow"
artist="ColdPlay"

# %%
recommended_df =kn_recommendation(normalized_tracks_df_withIndex, title,artist)
# Out:
# [2.22044605e-16 9.09231887e-03 1.24894262e-02 1.34971972e-02
#  1.44141258e-02 1.53538168e-02 1.55877931e-02 1.56328341e-02
#  1.60630712e-02 1.71189721e-02]
# [[2083 1596  221 1661   68 1338  229  313 1100  446]]
# [('yellow', 'coldplay'), ('she wolf', 'shakira'), ('blinding lights', 'the weeknd'), ('somewhere only we know', 'keane'), ('all i ever wanted - radio edit', 'basshunter'), ('only love can hurt like this', 'paloma faith'), ('bodak yellow', 'cardi b'), ('chandelier', 'sia'), ('love on the brain', 'rihanna'), ('domino', 'jessie j')]

# %%
recommendation_visualisation(recommended_df)

# %% [markdown]
# Resource:
#
# https://www.kaggle.com/datasets/conorvaneden/best-songs-on-spotify-for-every-year-2000-2023
#
# https://www.kaggle.com/datasets/lehaknarnauli/spotify-datasets?select=tracks.csv
#
# https://www.kaggle.com/code/typewind/draw-a-radar-chart-with-python-in-a-simple-way/notebook
#
# https://everydaycodings.medium.com/anime-recommendation-system-collaborative-method-ca3e84ee41a0
#
# https://medium.com/swlh/spotify-song-prediction-and-recommendation-system-b3bbc71398ad
